# %%
path="CBOW(Ass5)/CBOW.txt"

# %%
with open(path,'r') as file:
    file_contents=file.read()

# %%
file_contents
# Out:
# 'The speed of transmission is an important point of difference between the two viruses. Influenza has a shorter median incubation period (the time from infection to appearance of symptoms) and a shorter serial interval (the time between successive cases) than COVID-19 virus. The serial interval for COVID-19 virus is estimated to be 5-6 days, while for influenza virus, the serial interval is 3 days. This means that influenza can spread faster than COVID-19. \n\nFurther, transmission in the first 3-5 days of illness, or potentially pre-symptomatic transmission â€“transmission of the virus before the appearance of symptoms â€“ is a major driver of transmission for influenza. In contrast, while we are learning that there are people who can shed COVID-19 virus 24-48 hours prior to symptom onset, at present, this does not appear to be a major driver of transmission. \n\nThe reproductive number â€“ the number of secondary infections generated from one infected individual â€“ is understood to be between 2 and 2.5 for COVID-19 virus, higher than for influenza. However, estimates for both COVID-19 and influenza viruses are very context and time-specific, making direct comparisons more difficult.  '

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import GlobalAveragePooling1D, Embedding, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics.pairwise import cosine_similarity

# %%
sentences = file_contents.split('.')

# Tokenize the sentences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
total_words = len(tokenizer.word_index) + 1

# Generate context-target pairs for training
window_size = 3
tokenized_sentences = tokenizer.texts_to_sequences(sentences)

data, labels = [], []
for sentence in tokenized_sentences:
    for i, target_word in enumerate(sentence):
        context = [
            sentence[j] for j in range(i - window_size, i + window_size + 1)
            if j != i and 0 <= j < len(sentence)
        ]
        data.append(context)
        labels.append(target_word)

# Convert data and labels to numpy arrays
data = pad_sequences(data)
labels = np.array(labels)

# %%
model=Sequential()
model.add(Embedding(input_dim=total_words,output_dim=50,input_length=window_size*2))
model.add(GlobalAveragePooling1D())
model.add(Dense(total_words,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 6, 50)             5150
#
#  global_average_pooling1d_2  (None, 50)                0
#   (GlobalAveragePooling1D)
#
#  dense_2 (Dense)             (None, 103)               5253
#
# =================================================================
# Total params: 10403 (40.64 KB)
# Trainable params: 10403 (40.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(data,labels,epochs=200,verbose=1)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 0s 4ms/step - loss: 4.6345 - accuracy: 0.0101
# Epoch 2/200
# 7/7 [==============================] - 0s 806us/step - loss: 4.6249 - accuracy: 0.0556
# Epoch 3/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.6172 - accuracy: 0.1061
# Epoch 4/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.6098 - accuracy: 0.1465
# Epoch 5/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.6021 - accuracy: 0.1919
# Epoch 6/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.5942 - accuracy: 0.1818
# Epoch 7/200
# 7/7 [==============================] - 0s 965us/step - loss: 4.5857 - accuracy: 0.1919
# Epoch 8/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.5770 - accuracy: 0.2020
# Epoch 9/200
# 7/7 [==============================] - 0s 751us/step - loss: 4.5676 - accuracy: 0.1919
# Epoch 10/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.5576 - accuracy: 0.1869
# Epoch 11/200
# 7/7 [==============================] - 0s 975us/step - loss: 4.5467 - accuracy: 0.1869
# Epoch 12/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.5352 - accuracy: 0.1869
# Epoch 13/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.5226 - accuracy: 0.2020
# Epoch 14/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.5088 - accuracy: 0.2071
# Epoch 15/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.4936 - accuracy: 0.2071
# Epoch 16/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.4780 - accuracy: 0.2172
# Epoch 17/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.4604 - accuracy: 0.2172
# Epoch 18/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.4418 - accuracy: 0.2172
# Epoch 19/200
# 7/7 [==============================] - 0s 720us/step - loss: 4.4223 - accuracy: 0.2121
# Epoch 20/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.4011 - accuracy: 0.2121
# Epoch 21/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.3793 - accuracy: 0.2121
# Epoch 22/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.3569 - accuracy: 0.2020
# Epoch 23/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.3334 - accuracy: 0.1970
# Epoch 24/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.3087 - accuracy: 0.1869
# Epoch 25/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.2819 - accuracy: 0.1869
# Epoch 26/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4
200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.6166 - accuracy: 0.7323
# Epoch 148/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.6035 - accuracy: 0.7374
# Epoch 149/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5904 - accuracy: 0.7525
# Epoch 150/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5786 - accuracy: 0.7576
# Epoch 151/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5658 - accuracy: 0.7576
# Epoch 152/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5537 - accuracy: 0.7626
# Epoch 153/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5411 - accuracy: 0.7576
# Epoch 154/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5291 - accuracy: 0.7576
# Epoch 155/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5162 - accuracy: 0.7677
# Epoch 156/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5052 - accuracy: 0.7677
# Epoch 157/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4924 - accuracy: 0.7778
# Epoch 158/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4811 - accuracy: 0.7828
# Epoch 159/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4695 - accuracy: 0.7828
# Epoch 160/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4577 - accuracy: 0.7828
# Epoch 161/200
# 7/7 [==============================] - 0s 779us/step - loss: 1.4460 - accuracy: 0.7778
# Epoch 162/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4354 - accuracy: 0.7778
# Epoch 163/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4237 - accuracy: 0.7828
# Epoch 164/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4125 - accuracy: 0.7879
# Epoch 165/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4011 - accuracy: 0.7879
# Epoch 166/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3896 - accuracy: 0.7879
# Epoch 167/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3787 - accuracy: 0.7929
# Epoch 168/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3679 - accuracy: 0.7929
# Epoch 169/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3573 - accuracy: 0.7980
# Epoch 170/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3462 - accuracy: 0.7980
# Epoch 171/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3349 - accuracy: 0.8030
# Epoch 172/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3249 - accuracy: 0.8081
# Epoch 173/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3140 - accuracy: 0.8131
# Epoch 174/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3030 - accuracy: 0.8182
# Epoch 175/200
# 7/7 [==============================] - 0s 664us/step - loss: 1.2929 - accuracy: 0.8232
# Epoch 176/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2831 - accuracy: 0.8232
# Epoch 177/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2719 - accuracy: 0.8232
# Epoch 178/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2617 - accuracy: 0.8333
# Epoch 179/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2514 - accuracy: 0.8333
# Epoch 180/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2407 - accuracy: 0.8384
# Epoch 181/200
# 7/7 [==============================] - 0s 846us/step - loss: 1.2310 - accuracy: 0.8333
# Epoch 182/200
# 7/7 [==============================] - 0s 477us/step - loss: 1.2209 - accuracy: 0.8384
# Epoch 183/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2107 - accuracy: 0.8485
# Epoch 184/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2009 - accuracy: 0.8636
# Epoch 185/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1909 - accuracy: 0.8687
# Epoch 186/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1808 - accuracy: 0.8636
# Epoch 187/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1715 - accuracy: 0.8636
# Epoch 188/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1619 - accuracy: 0.8636
# Epoch 189/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1524 - accuracy: 0.8737
# Epoch 190/200
# 7/7 [==============================] - 0s 639us/step - loss: 1.1432 - accuracy: 0.8737
# Epoch 191/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1337 - accuracy: 0.8788
# Epoch 192/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1246 - accuracy: 0.8788
# Epoch 193/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1146 - accuracy: 0.8838
# Epoch 194/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1057 - accuracy: 0.8788
# Epoch 195/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0961 - accuracy: 0.8838
# Epoch 196/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0871 - accuracy: 0.8889
# Epoch 197/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0781 - accuracy: 0.8939
# Epoch 198/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0693 - accuracy: 0.8939
# Epoch 199/200
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0603 - accuracy: 0.8939
# Epoch 200/200
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0513 - accuracy: 0.8939

# %%
word_embeddings= model.layers[0].get_weights()[0]

# %%
from sklearn.metrics.pairwise import cosine_similarity

target_word = 'influenza'
target_embedding = word_embeddings[tokenizer.word_index[target_word]]

similarities = cosine_similarity(target_embedding.reshape(1, -1), word_embeddings)[0]
most_similar_indices = similarities.argsort()[-5:][::-1]
    
most_similar_words = [word for word, idx in tokenizer.word_index.items() if idx in most_similar_indices]

print(f"Most similar words to '{target_word}': {most_similar_words}")
# Out:
# Most similar words to 'influenza': ['influenza', 'can', 'means', 'spread', 'people']
